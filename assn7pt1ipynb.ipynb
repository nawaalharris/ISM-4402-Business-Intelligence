# %% [markdown]
# <a href="https://colab.research.google.com/github/nawaalharris/ISM-4402-Business-Intelligence/blob/master/assn7pt1ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
names = ['Bob','Jessica','Mary','John','Mel']
grades = [76, 83, 77, 78, 95]
GradeList = zip(names,grades)
df = pd.DataFrame(data= GradeList,
                  columns=['Names','Grades'])
# %matplotlib inline
df.plot()

# %%
import matplotlib.pyplot as plt
df.plot()
displayText = "Wow"
xloc = 1
yloc = df['Grades'].min()
xtext = -310
ytext = 1
plt.annotate(displayText,
             xy=(xloc, yloc),
             xytext=(xtext, ytext),
             xycoords=('axes fraction','data'),
             textcoords='offset points')
# Out:
# Text(-310, 1, 'Wow')
